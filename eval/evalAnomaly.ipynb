# %%
# --- CHECK GPU ---
# !nvidia-smi

# --- CLONE YOUR REPO ---
# !rm -rf MaskArchitectureAnomaly_CourseProject
# !git clone https://github.com/r-anguilletti/MaskArchitectureAnomaly_CourseProject.git

# %cd MaskArchitectureAnomaly_CourseProject

# --- OPTIONAL: show files ---
# !ls -R .
# Out:
# Tue Nov 25 17:09:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Cloning into 'MaskArchitectureAnomaly_CourseProject'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 117 (delta 22), reused 98 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 26.87 MiB | 30.27 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/MaskArchitectureAnomaly_CourseProject
# .:
# eomt  eval  README.md  trained_models
#
# ./eomt:
# configs   docs		   __init__.py	main.py  README.md	   training
# datasets  inference.ipynb  LICENSE	models	 requirements.txt
#
# ./eomt/configs:
# dinov2
#
# ./eomt/configs/dinov2:
# cityscapes
#
# ./eomt/configs/dinov2/cityscapes:
# semantic
#
# ./eomt/configs/dinov2/cityscapes/semantic:
# eomt_base_640.yaml  eomt_large_1024.yaml
#
# ./eomt/datasets:
# ade20k_panoptic.py	coco_instance.py  __init__.py
# ade20k_semantic.py	coco_panoptic.py  lightning_data_module.py
# cityscapes_semantic.py	dataset.py	  transforms.py
#
# ./eomt/docs:
# index.html  static
#
# ./eomt/docs/static:
# css  images  js
#
# ./eomt/docs/static/css:
# bulma-carousel.min.css	bulma.min.css	      fontawesome.all.min.css
# bulma.css.map.txt	bulma-slider.min.css  index.css
#
# ./eomt/docs/static/images:
# apple-touch-icon.png  favicon.svg	web-app-manifest-192x192.png
# arch.svg	      site.webmanifest	web-app-manifest-512x512.png
# favicon-96x96.png     teaser_arch.svg
# favicon.ico	      teaser_plot.svg
#
# ./eomt/docs/static/js:
# bulma-carousel.js      bulma-slider.js	    fontawesome.all.min.js
# bulma-carousel.min.js  bulma-slider.min.js  index.js
#
# ./eomt/models:
# eomt.py  __init__.py  scale_block.py  vit.py
#
# ./eomt/training:
# __init__.py			 mask_classification_panoptic.py
# lightning_module.py		 mask_classification_semantic.py
# mask_classification_instance.py  two_stage_warmup_poly_schedule.py
# mask_classification_loss.py
#
# ./eval:
# dataset.py	   evalAnomaly.py	      eval_iou.py  results.txt
# erfnet_nobn.py	   eval_cityscapes_color.py   iouEval.py   transform.py
# erfnet.py	   eval_cityscapes_server.py  __pycache__
# evalAnomaly.ipynb  eval_forwardTime.py	      README.md
#
# ./eval/__pycache__:
# dataset.cpython-38.pyc	iouEval.cpython-38.pyc
# erfnet.cpython-38.pyc	transform.cpython-38.pyc
#
# ./trained_models:
# erfnet_encoder_pretrained.pth.tar  erfnet_pretrained.pth

# %%
# 3. Installa le dipendenze
# !pip install torch torchvision
# !pip install "opencv-python<4.10"  # Per evitare l'errore di numpy
# !pip install scikit-learn matplotlib visdom pillow
# !pip install ood-metrics # Se usi la libreria standard, altrimenti usa il file locale
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !wget https://raw.githubusercontent.com/SegmentMeIfYouCan/road-anomaly-benchmark/master/methods/ood_metrics.py -O eval/ood_metrics.py

# %%
import sys
sys.path.append("/content/MaskArchitectureAnomaly_CourseProject/eval")

from erfnet import ERFNet
from ood_metrics import fpr_at_95_tpr

print("Imports OK")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2313829987.py in <cell line: 0>()
#       3
#       4 from erfnet import ERFNet
# ----> 5 from ood_metrics import fpr_at_95_tpr
#       6
#       7 print("Imports OK")
#
# ModuleNotFoundError: No module named 'ood_metrics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd eval
# !python evalAnomaly.py --input
